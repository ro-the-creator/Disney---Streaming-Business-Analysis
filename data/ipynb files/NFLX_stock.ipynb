# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/Marcy_Student/Desktop/m0-Final_Project/data/csv files/NFLX.csv')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             Date        Open        High         Low       Close   Adj Close  \
# 0     2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1     2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2     2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3     2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4     2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...          ...         ...         ...         ...         ...         ...
# 5417  2023-11-29  479.000000  480.989990  474.489990  477.190002  477.190002
# 5418  2023-11-30  475.309998  478.589996  470.420013  473.970001  473.970001
# 5419  2023-12-01  473.170013  475.230011  464.600006  465.739990  465.739990
# 5420  2023-12-04  460.989990  461.200012  451.200012  453.899994  453.899994
# 5421  2023-12-05  450.700012  456.390015  449.579987  455.149994  455.149994
#
#          Volume
# 0     104790000
# 1      11104800
# 2       6609400
# 3       6757800
# 4      10154200
# ...         ...
# 5417    2855500
# 5418    4287300
# 5419    4338100
# 5420    5157700
# 5421    3261100
#
# [5422 rows x 7 columns]>

# %%
# Creating a filtered_df between Nov 12, 2019 - Nov 12, 2022

filtered_nov_df = pd.Series({
    'Date': pd.date_range(start='2019-01-02', end='2022-12-31')
    })

filtered_df = df.loc[df['Date'] > '2019-01-12']

print(filtered_df)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 4189  2019-01-14  334.239990  335.480011  329.130005  332.940002  332.940002
# 4190  2019-01-15  349.600006  357.220001  347.000000  354.640015  354.640015
# 4191  2019-01-16  354.000000  358.850006  348.109985  351.390015  351.390015
# 4192  2019-01-17  349.500000  355.790009  346.410004  353.190002  353.190002
# 4193  2019-01-18  351.970001  353.000000  336.730011  339.100006  339.100006
# ...          ...         ...         ...         ...         ...         ...
# 5417  2023-11-29  479.000000  480.989990  474.489990  477.190002  477.190002
# 5418  2023-11-30  475.309998  478.589996  470.420013  473.970001  473.970001
# 5419  2023-12-01  473.170013  475.230011  464.600006  465.739990  465.739990
# 5420  2023-12-04  460.989990  461.200012  451.200012  453.899994  453.899994
# 5421  2023-12-05  450.700012  456.390015  449.579987  455.149994  455.149994
#
#         Volume
# 4189  10499600
# 4190  21181200
# 4191  15385500
# 4192  18871200
# 4193  26621000
# ...        ...
# 5417   2855500
# 5418   4287300
# 5419   4338100
# 5420   5157700
# 5421   3261100
#
# [1233 rows x 7 columns]

# %%
# changing columns to int

filtered_df['Open'] = filtered_df['Open'].astype(int)
filtered_df['High'] = filtered_df['High'].astype(int)
filtered_df['Low'] = filtered_df['Low'].astype(int)
filtered_df['Close'] = filtered_df['Close'].astype(int)
filtered_df['Adj Close'] = filtered_df['Adj Close'].astype(int)
filtered_df.dtypes
# Out:
# /var/folders/gs/yv3dj4zx2tgdd5tw701ypspm0000gp/T/ipykernel_74992/1189220741.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Open'] = filtered_df['Open'].astype(int)
# /var/folders/gs/yv3dj4zx2tgdd5tw701ypspm0000gp/T/ipykernel_74992/1189220741.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['High'] = filtered_df['High'].astype(int)
# /var/folders/gs/yv3dj4zx2tgdd5tw701ypspm0000gp/T/ipykernel_74992/1189220741.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Low'] = filtered_df['Low'].astype(int)
# /var/folders/gs/yv3dj4zx2tgdd5tw701ypspm0000gp/T/ipykernel_74992/1189220741.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Close'] = filtered_df['Close'].astype(int)
# /var/folders/gs/yv3dj4zx2tgdd5tw701ypspm0000gp/T/ipykernel_74992/1189220741.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Adj Close'] = filtered_df['Adj Close'].astype(int)
# Date         object
# Open          int64
# High          int64
# Low           int64
# Close         int64
# Adj Close     int64
# Volume        int64
# dtype: object

# %%
fdf_mean = np.mean(filtered_df["Close"])
fdf_median = np.median(filtered_df["Close"])
fdf_std = np.std(filtered_df["Close"])
Q1 = np.percentile(filtered_df['Close'], 25)
Q3 = np.percentile(filtered_df['Close'], 75)
IQR = np.percentile(filtered_df['Close'], 75) - np.percentile(filtered_df['Close'], 25)

print("Closing Stock Price Analysis From Jan 01, 2019 - Dec 31, 2022")
print("Mean :"," $", fdf_median)
print("Median :"," $", fdf_mean)
print("---------------------------")
print("Strd Dev. :"," $", fdf_std)
print("Q1 :", "$", Q1)
print("Q3 :", "$", Q3)
print("IQR :", "$", IQR)
# Out:
# Closing Stock Price Analysis From Jan 01, 2019 - Dec 31, 2022
# Mean :  $ 379.0
# Median :  $ 400.978102189781
# ---------------------------
# Strd Dev. :  $ 115.5931226284402
# Q1 : $ 320.0
# Q3 : $ 496.0
# IQR : $ 176.0

# %%
# Netflix
markers = [210]
plt.plot(filtered_df["Date"], filtered_df['Close'], 'r-', markevery=markers, marker='D', ms=10, mfc='b', label='Nov 12, 2019 | Launch of Disney+')
plt.xlabel("Date (Yr)")
plt.ylabel("Closing Value ($)")
plt.title("Netflix Closing Stock Value Jan 2019 - Dec 2022")
plt.grid(True)
plt.xticks([244, 497, 749], ['2020', '2021', '2022'])
plt.axhline(y=379, color='g', ls='--', label='Mean Stock Price | $379')
plt.legend()
plt.show()

# %%
x = filtered_df.iloc[411, 4] - filtered_df.iloc[289, 4]
y = x/filtered_df.iloc[289, 5] * 100
print('Percent Increase from Mar 9, 2020 - Aug 31, 2020:', f"{y:.2f}%")
# Out:
# Percent Increase from Mar 9, 2020 - Aug 31, 2020: 52.89%
